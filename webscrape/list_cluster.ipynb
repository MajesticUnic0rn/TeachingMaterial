# %% [markdown]
# Just a casual walk thru of list comprehension in Python.

# %%
nums=[54,22,15,455,223,170]
even=[]

# %%
for num in nums:
    if num%2==0:
        even.append(num)

# %%
even
# Out:
# [54, 22, 170]

# %%
even=[num for num in nums if num%2==0]
even
# Out:
# [54, 22, 170]

# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
x = np.array([[36, 7000], [45, 6000], [70, 7100],[20, 2000], [25, 2200], [15, 1800]]) ## age and salary
kmeans = KMeans(n_clusters=2)
kmeans.fit(x)

# %%
# Out:
# KMeans(n_clusters=2)

# %%
kmeans
# Out:
# array([1, 1, 1, 0, 0, 0], dtype=int32)

# %%
x
# Out:
# array([[  36, 7000],
#        [  45, 6000],
#        [  70, 7100],
#        [  20, 2000],
#        [  25, 2200],
#        [  15, 1800]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Your data
x = np.array([[36, 7000], [45, 6000], [70, 7100], [20, 2000], [25, 2200], [15, 1800]])  # age and salary

# KMeans clustering
kmeans = KMeans(n_clusters=2)
kmeans.fit(x)

# Cluster centers
centroids = kmeans.cluster_centers_

# Cluster labels
labels = kmeans.labels_

# Plotting
plt.figure(figsize=(10, 6))
colors = ["blue", "green"]

# Plot each data point
for i in range(len(x)):
    plt.scatter(x[i][0], x[i][1], c=colors[labels[i]], s=50)

# Plot centroids
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=150, c='r')

plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('KMeans Clustering Visualization')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets as datasets
input_iris=datasets.load_iris()

# %%
input_df = pd.DataFrame(data=input_iris.data,  
                  columns=input_iris.feature_names) 
# If you want to add the target (species) to the DataFrame
input_df['species'] = input_iris.target
# Optionally, map the numeric species to their original names
input_df['species'] = input_df['species'].map(dict(enumerate(input_iris.target_names)))

# %%
input_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
x=input_df.iloc[:,0:4]

# %%
for i in range (1,6):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(x)
    input_df['cluster']=kmeans.predict(x)
    sns.pairplot(input_df, hue='cluster')
    plt.show()

# %%
WCCS=[]

# %%
for i in range (1,6):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(x)
    WCCS.append(kmeans.inertia_)
plt.plot(range(1,6),WCCS)
plt.xlabel('Number of clusters')
plt.ylabel('WCCS')
plt.show()

# %%
WCCS
# Out:
# [681.3706,
#  152.34795176035792,
#  78.8556658259773,
#  57.38387326549491,
#  46.47223015873016]

# %%
## find the centroids
kmeans.cluster_centers_
# Out:
# array([[6.24722222, 2.84722222, 4.775     , 1.575     ],
#        [5.006     , 3.428     , 1.462     , 0.246     ],
#        [7.475     , 3.125     , 6.3       , 2.05      ],
#        [6.52916667, 3.05833333, 5.50833333, 2.1625    ],
#        [5.53214286, 2.63571429, 3.96071429, 1.22857143]])
